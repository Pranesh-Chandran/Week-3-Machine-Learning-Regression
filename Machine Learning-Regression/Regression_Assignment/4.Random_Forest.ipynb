# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size =0.30, random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
#Model Creation
#criterion{“squared_error”, “absolute_error”, “friedman_mse”, “poisson”}, default=”squared_error”
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 50, random_state=0, criterion="absolute_error", max_features="sqrt" )

# %%
regressor.fit(x_train,y_train)
# Out:
# C:\Users\Pranesh\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='absolute_error', max_features='sqrt',
#                       n_estimators=50, random_state=0)

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([10727.4099232,  9039.8109027, 43969.713727 , 13127.4464445,
#        10754.6211256, 10793.8000008,  2057.364916 , 10692.5564152,
#         7210.468307 ,  6725.162002 ,  6214.1981102, 12836.6464513,
#         8178.9128467,  5113.8385642, 22929.0750912, 11357.0561878,
#        13333.2040776,  4865.6885026,  6810.4381224, 31677.6782712,
#        23856.7836135, 14079.354458 , 11474.2204808, 26465.5227334,
#         3618.0625858,  6688.9730088,  4552.4477656,  7868.487845 ,
#         3855.279956 , 11077.4582354,  8563.3837242, 46370.132331 ,
#        14335.805728 , 14335.4206176, 17457.8495426,  4071.832552 ,
#         8540.132348 , 37628.0764216, 39226.158775 ,  2480.0585525,
#         6017.0211574,  3740.5893734, 21163.5584603, 47034.1845734,
#        36504.366788 ,  4401.0170858, 11368.7434108,  6545.914078 ,
#         6012.5346962, 12506.3612408,  4801.369858 ,  4627.9820724,
#        25625.8908606, 43624.5791438, 11673.350439 , 11602.135986 ,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8716849080926139

# %%
#Save model
#Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')
import pickle
filename = "Finalized_model_possion_regressor.sav"
pickle.dump(regressor, open(filename, 'wb'))
age = int(input("Enter your age :"))
bmi = int(input("Enter your bmi :"))
children = int(input("Enter your children count :"))
charges = int(input("Enter your charges :"))
sex = int(input("Enter your sex Male =1 or female =0 :"))
smoker = int(input("Enter smoker = 1 otherwise = 0  :"))
load_model = pickle.load(open(filename,'rb'))
r_result = load_model.predict([[12,5,3,4,7]])
r_result
# Out:
# Enter your age : 25
# Enter your bmi : 2566
# Enter your children count : 0
# Enter your charges : 25874
# Enter your sex Male =1 or female =0 : 1
# Enter smoker = 1 otherwise = 0  : 1
# array([46275.0177512])

# %% [markdown]
# #####
