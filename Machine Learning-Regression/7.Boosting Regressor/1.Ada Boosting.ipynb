# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size =0.30, random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
#model Creation
#from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
#criterion{“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}
# best, random
regressor = AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
regressor.fit(x_train,y_train)
# Out:
# C:\Users\Pranesh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([14553.50784521, 13802.56972465, 47865.29543781, 14444.51254404,
#        12907.00232984,  6912.31668256,  5791.61329319, 14553.50784521,
#         8687.92288728,  8663.98408105,  6912.31668256, 14553.50784521,
#        13802.56972465,  6912.31668256, 18971.33402691, 14553.50784521,
#        14444.51254404,  8663.98408105,  6912.31668256, 37427.68127192,
#        26288.19508231, 14553.50784521, 14444.51254404, 26288.19508231,
#         5982.00008099,  8663.98408105,  6912.31668256,  8687.92288728,
#         6912.31668256, 13802.56972465,  6912.31668256, 47865.29543781,
#        14444.51254404, 14444.51254404, 18971.33402691,  6912.31668256,
#        13802.56972465, 37427.68127192, 40762.69968952,  5982.00008099,
#         6912.31668256,  6912.31668256, 20052.64576923, 47865.29543781,
#        37427.68127192,  8663.98408105, 14553.50784521,  6912.31668256,
#         6912.31668256, 14553.50784521,  5982.00008099,  5791.61329319,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8618083410771146

# %%
#Save Model
import pickle

# %%
filename="BoostingAlgorithm.sav"
pickle.dump(regressor,open(filename,'wb'))
loaded_model=pickle.load(open("BoostingAlgorithm.sav",'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 29
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Predict = loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_Prediction={}".format(Future_Predict))
# Out:
# Future_Prediction=[47865.29543781]
