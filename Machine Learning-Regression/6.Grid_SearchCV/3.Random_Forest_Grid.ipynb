# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size =0.30, random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
#Model Creation
#criterion{“squared_error”, “absolute_error”, “friedman_mse”, “poisson”}, default=”squared_error”
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid, refit = True, verbose = 3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_prediction= grid.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test,grid_prediction)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8695552485947133

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002865      0.000734         0.000000        0.000000
# 1        0.002480      0.000766         0.000000        0.000000
# 2        0.063658      0.006193         0.008511        0.001666
# 3        0.416996      0.013998         0.025292        0.002395
# 4        0.054385      0.013476         0.005776        0.000765
# 5        0.378690      0.009032         0.024576        0.001678
# 6        0.001318      0.000462         0.000000        0.000000
# 7        0.001136      0.000256         0.000000        0.000000
# 8        0.092740      0.003111         0.004919        0.000157
# 9        1.328839      0.054494         0.040028        0.004288
# 10       0.101887      0.005867         0.005079        0.000396
# 11       1.548153      0.081332         0.046245        0.003837
# 12       0.002162      0.000446         0.000000        0.000000
# 13       0.001391      0.000243         0.000000        0.000000
# 14       0.050543      0.002200         0.008172        0.002083
# 15       0.713289      0.014286         0.045280        0.002508
# 16       0.079934      0.002731         0.010396        0.001193
# 17       0.709806      0.026079         0.047416        0.001719
# 18       0.002225      0.000324         0.000000        0.000000
# 19       0.001993      0.000108         0.000000        0.000000
# 20       0.096075      0.005333         0.011709        0.001770
# 21       0.756098      0.014087         0.045125        0.001146
# 22       0.088921      0.001177         0.009356        0.001636
# 23       0.723839      0.016490         0.039376        0.005332
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               auto                  10
# 1    squared_error               auto                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               auto                  10
# 7   absolute_error               auto                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               auto                  10
# 19         poisson               auto                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.859736
# 3   {'criterion': 'squared_error', 'max_features':...           0.864100
# 4   {'criterion': 'squared_error', 'max_features':...           0.843638
# 5   {'criterion': 'squared_error', 'max_features':...           0.866294
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.834656
# 9   {'criterion': 'absolute_error', 'max_features'...           0.860908
# 10  {'criterion': 'absolute_error', 'max_features'...           0.862827
# 11  {'criterion': 'absolute_error', 'max_features'...           0.859583
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.832045
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.866492
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.867562
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.860549
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.852307
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.870673
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.830802
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.855591
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.778499           0.800962           0.812669
# 3            0.790700           0.804668           0.823402
# 4            0.796538           0.788661           0.812251
# 5            0.792494           0.814213           0.825187
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.769291           0.781206           0.792129
# 9            0.787516           0.810942           0.828615
# 10           0.778222           0.781863           0.817586
# 11           0.794011           0.808947           0.822220
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.767831           0.787742           0.802966
# 15           0.794529           0.807132           0.826084
# 16           0.776960           0.798192           0.798543
# 17           0.795386           0.805311           0.836098
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.768657           0.805545           0.818792
# 21           0.795890           0.808278           0.832781
# 22           0.776628           0.797641           0.814814
# 23           0.785120           0.810238           0.826847
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.764098         0.803193        0.032955                9
# 3            0.769679         0.810510        0.032037                7
# 4            0.750617         0.798341        0.030397               11
# 5            0.766808         0.812999        0.033300                3
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.761710         0.787798        0.025616               15
# 9            0.772345         0.812065        0.031116                5
# 10           0.742678         0.796635        0.040716               12
# 11           0.771118         0.811176        0.029562                6
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.741450         0.786407        0.030741               16
# 15           0.769962         0.812840        0.032436                4
# 16           0.731687         0.794589        0.043866               13
# 17           0.769044         0.813277        0.031924                2
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.750927         0.799246        0.036076               10
# 21           0.771158         0.815756        0.033898                1
# 22           0.745916         0.793160        0.029702               14
# 23           0.761922         0.807944        0.032471                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 27
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[49895.020162]
