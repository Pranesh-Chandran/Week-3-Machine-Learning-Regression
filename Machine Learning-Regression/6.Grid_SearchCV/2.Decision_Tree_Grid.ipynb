# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size =0.30, random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
#model Creation
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error','poisson'], 
              'max_features':['None', 'sqrt', 'log2'],
              'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs =-1)

# %%
# fitting the model for grid search
import warnings
warnings.filterwarnings('ignore')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re = grid.cv_results_
#print(re)
grid_prediction = grid.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test,grid_prediction)
print("The R2_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R2_score value for best parameter {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}: 0.6664587970475047

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001451      0.000086         0.000000        0.000000
# 1        0.000961      0.000134         0.000000        0.000000
# 2        0.007913      0.001311         0.004425        0.001992
# 3        0.007312      0.001044         0.004253        0.000283
# 4        0.007805      0.000968         0.003792        0.000346
# 5        0.006344      0.001386         0.004824        0.001885
# 6        0.001440      0.000438         0.000000        0.000000
# 7        0.005380      0.006962         0.000000        0.000000
# 8        0.014739      0.005723         0.007062        0.002936
# 9        0.018732      0.007028         0.007361        0.001699
# 10       0.015141      0.008983         0.004276        0.000661
# 11       0.008522      0.001108         0.004919        0.000734
# 12       0.001879      0.000620         0.000000        0.000000
# 13       0.001852      0.000733         0.000000        0.000000
# 14       0.023107      0.003650         0.004851        0.001512
# 15       0.017290      0.003357         0.003775        0.000484
# 16       0.024460      0.006762         0.003219        0.000873
# 17       0.017028      0.003905         0.003731        0.000603
# 18       0.002009      0.001259         0.000000        0.000000
# 19       0.002699      0.002239         0.000000        0.000000
# 20       0.007041      0.001044         0.003480        0.000726
# 21       0.006199      0.000557         0.003893        0.000658
# 22       0.007316      0.001651         0.003183        0.000610
# 23       0.006481      0.000810         0.003288        0.000394
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.703401
# 3   {'criterion': 'squared_error', 'max_features':...           0.704089
# 4   {'criterion': 'squared_error', 'max_features':...           0.698207
# 5   {'criterion': 'squared_error', 'max_features':...           0.655826
# 6   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 7   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.796877
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.668184
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.534164
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.458250
# 12  {'criterion': 'absolute_error', 'max_features'...                NaN
# 13  {'criterion': 'absolute_error', 'max_features'...                NaN
# 14  {'criterion': 'absolute_error', 'max_features'...           0.729142
# 15  {'criterion': 'absolute_error', 'max_features'...           0.625716
# 16  {'criterion': 'absolute_error', 'max_features'...           0.740435
# 17  {'criterion': 'absolute_error', 'max_features'...           0.681939
# 18  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.475431
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.731276
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.793884
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.656428
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.663559           0.640311           0.731768
# 3            0.628127           0.590245           0.526424
# 4            0.627323           0.651250           0.677372
# 5            0.560346           0.536082           0.566102
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.573911           0.594002           0.630223
# 9            0.502920           0.604417           0.563745
# 10           0.502653           0.662489           0.697608
# 11           0.558105           0.604386           0.519537
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.674080           0.658741           0.485359
# 15           0.677506           0.570223           0.629448
# 16           0.606107           0.669690           0.457352
# 17           0.693985           0.674128           0.585698
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.658334           0.653447           0.546931
# 21           0.521595           0.504509           0.629191
# 22           0.669459           0.623709           0.677712
# 23           0.621170           0.400211           0.625258
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.607397         0.669287        0.044205                2
# 3            0.586331         0.607043        0.058435               10
# 4            0.654075         0.661645        0.024197                3
# 5            0.529060         0.569483        0.045387               15
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.688546         0.656712        0.080187                4
# 9            0.545912         0.577036        0.056029               13
# 10           0.693197         0.618022        0.082831                8
# 11           0.580103         0.544076        0.051186               16
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.636742         0.636813        0.081649                6
# 15           0.557230         0.612025        0.043655                9
# 16           0.656980         0.626113        0.094659                7
# 17           0.637965         0.654743        0.039253                5
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.699870         0.606803        0.082868               11
# 21           0.614068         0.600128        0.081913               12
# 22           0.645392         0.682031        0.059045                1
# 23           0.557504         0.572114        0.091765               14

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 12
# BMI: 2
# Children: 23
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
future_prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_Prediction={}".format(future_prediction))
# Out:
# Future_Prediction=[36580.28216]
