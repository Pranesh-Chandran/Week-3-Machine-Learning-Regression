# %%
#importing libraries
#import numpy as np
#import matplotlib.pyplot as pt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first = True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size =0.30, random_state =0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
#Grid SearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'], 'C':[100, 500, 1000, 2000, 3000], 'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose = 3, n_jobs=-1)

# %%
# fitting the model for grid search
import warnings
warnings.filterwarnings('ignore')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 500, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
y_pred = grid.predict(x_test)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.038333      0.003645         0.018278        0.002274      100
# 1        0.028099      0.002351         0.006163        0.001560      100
# 2        0.039243      0.001748         0.008316        0.000722      100
# 3        0.034255      0.002012         0.005285        0.000405      100
# 4        0.035929      0.001665         0.017116        0.001451      100
# 5        0.032178      0.001615         0.006938        0.000730      100
# 6        0.043917      0.004574         0.009341        0.001269      100
# 7        0.036102      0.001663         0.005349        0.000254      100
# 8        0.041850      0.002003         0.015865        0.000823      500
# 9        0.038336      0.000662         0.005917        0.000366      500
# 10       0.044327      0.002693         0.008162        0.000389      500
# 11       0.049246      0.013703         0.005971        0.000944      500
# 12       0.041406      0.002633         0.016321        0.000537      500
# 13       0.036694      0.003177         0.005408        0.000415      500
# 14       0.043845      0.001984         0.008753        0.000743      500
# 15       0.036041      0.000731         0.005342        0.000464      500
# 16       0.044940      0.002809         0.016083        0.000301     1000
# 17       0.044746      0.009766         0.005700        0.000471     1000
# 18       0.046093      0.005729         0.008558        0.001053     1000
# 19       0.043454      0.002082         0.005731        0.000427     1000
# 20       0.045913      0.001218         0.015934        0.000762     1000
# 21       0.048827      0.009059         0.006412        0.000967     1000
# 22       0.044554      0.002929         0.008105        0.000546     1000
# 23       0.043392      0.002714         0.005234        0.000647     1000
# 24       0.052327      0.004834         0.017782        0.001785     2000
# 25       0.089128      0.012442         0.006054        0.000632     2000
# 26       0.044155      0.001943         0.008383        0.000654     2000
# 27       0.053552      0.004022         0.006013        0.000571     2000
# 28       0.051068      0.003237         0.017571        0.001514     2000
# 29       0.072622      0.010190         0.006313        0.000919     2000
# 30       0.054306      0.005995         0.010315        0.000989     2000
# 31       0.058471      0.005866         0.006828        0.001347     2000
# 32       0.068612      0.012263         0.024386        0.008585     3000
# 33       0.124923      0.051562         0.005874        0.000494     3000
# 34       0.044488      0.001901         0.008422        0.000756     3000
# 35       0.061386      0.004656         0.005247        0.000453     3000
# 36       0.052316      0.003579         0.016299        0.001386     3000
# 37       0.140942      0.059550         0.005641        0.000430     3000
# 38       0.051001      0.005444         0.012078        0.006570     3000
# 39       0.062681      0.004644         0.005448        0.000414     3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 1       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 2    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 3     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 4       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 5      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 6   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 7    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 8        {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.601529
# 9       {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.781613
# 10   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.434785
# 11    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.601152
# 12      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.601802
# 13     {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.780516
# 14  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.466661
# 15   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.601152
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.828670
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.846775
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.090896
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.657470
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.828795
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.846874
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.761871
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.657470
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0